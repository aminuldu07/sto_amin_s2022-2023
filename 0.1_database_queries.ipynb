# %% [markdown]
# # Database Queries
#
#
# This is the first notebook in a series of Jupyter Notebooks linked to the project titled "__Developing Mechanism-Based Models for Complex Toxicology Study Endpoints Using Standardized Electronic Submission Data__".  They should be somewhat ordinal, i.e., should be run in order as each Notebook could depend on results from a previous notebook.
#
# This notebook requires a dependency script, `send.py`, which contains an object that is a live instance to the database and can be queried, etc.  This script requires two variables to be configured, `db_dir` and `send_db_file`.  `db_dir` should point to the directory that contains the SQLlite database and `send_db_file` should be the SQLite database file itself.
#
# This notebook simply is simply just to get database queries for the SEND manuscript.

# %%
from send import send_db
import pandas as pd

ts = send_db.generic_query('SELECT * FROM TS')

# %%
print(f"There are {ts.TSPARMCD.nunique()} TSPARMCDs")
print('\n'.join(ts.TSPARMCD.unique()))
# Out:
# There are 101 TSPARMCDs
# AGETXT
# AGEU
# DOSDUR
# EXPENDTC
# EXPSTDTC
# GLPTYP
# HOUSEGRP
# RECSAC
# ROUTE
# SDESIGN
# SNDCTVER
# SNDIGVER
# SPECIES
# SPLRLOC
# SPLRNAM
# SPREFID
# SSPONSOR
# SSTYP
# STCAT
# STDIR
# STITLE
# STRAIN
# STSTDTC
# TFCNTRY
# TRMSAC
# TRT
# TRTCAS
# TRTV
# TSTFLOC
# TSTFNAM
# ASOCSTDY
# BEDCHNG
# BEDDING
# DIET
# DOSENDTC
# DOSSTDTC
# ENVTEMP
# ENVTEMPU
# FEEDREG
# GLPFL
# HOUSETYP
# HUMIDT
# HUMIDTU
# IACUC
# IDMETH
# LIGHT
# MTHTRM
# PCLASS
# SEXPOP
# SRANDOM
# STENDTC
# TRTUNII
# WATER
# WTRDLVRY
# STMON
# PINV
# TRTDOSU
# SLENGTH
# PLANFSUB
# PLANMSUB
# SPLANSUB
# TSCNTRY
# TSLOC
# TSNAM
# TKDESC
# AGE
# PPL
# PDOSFRQ
# CNTRBSC
# STRPSTAT
# SBSTRAIN
# TOTANPCH
# ALTSTDID
# INTSAC
# PPTCNAM
# PPTEGID
# PPTEGSYM
# PPTMDA
# STOBJ
# STRPNUM
# TANUM
# AMGPNUM
# GPSNUM
# THAGTMOD
# QATYPE
# PROTNUM
# STRPDT
# PREPPER
# PDFORM
# SPFIND
# LOT
# TESTID
# TCNTRL
# PKANIND
# DEFVER
# DOSFRQ
# PCLAS
# PRJCTID
# CLASS
# TELMIND
# WATRDLVRY

# %%
animals = send_db.get_all_animals()

animals.head()
# Out:
#     STUDYID  ID        USUBJID SPECIES  STRAIN SEX
# 0  00086621   1  00086621-1001     DOG  BEAGLE   M
# 1  00086621   1  00086621-1002     DOG  BEAGLE   M
# 2  00086621   1  00086621-1003     DOG  BEAGLE   M
# 3  00086621   1  00086621-2001     DOG  BEAGLE   M
# 4  00086621   1  00086621-2002     DOG  BEAGLE   M

# %% [markdown]
# ### Results section 3.1

# %%
animals.USUBJID.nunique()
# Out:
# 169839

# %%
animals.SPECIES.value_counts()
# Out:
# RAT           95464
# MOUSE         42770
# MONKEY        16980
# DOG           11629
# PIG            1657
# RABBIT         1426
# GUINEA PIG      334
# CAT             178
# MINIPIG           2
# Name: SPECIES, dtype: int64

# %%
95464/169839
# Out:
# 0.5620852689900435

# %%
training = pd.read_csv('data/RAT/RAT_training_data.csv')
# Out:
# /hive/Anaconda3-2020.02/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
training.USUBJID.nunique()
# Out:
# 17285

# %% [markdown]
# ### Results section 3.2

# %%
mi = send_db.generic_query('SELECT * FROM MI')

mi['MISPEC'] = mi['MISPEC'].str.upper()
mi['MISTRESC'] = mi['MISTRESC'].str.upper()

liver = mi[mi.MISPEC == 'LIVER']

# %%
print(mi.MISPEC.value_counts())
print(mi.shape[0])
# Out:
# LIVER                                     114636
# KIDNEY                                    105560
# GLAND, ADRENAL                             97592
# SPLEEN                                     89112
# THYMUS                                     87497
#                                            ...
# ESOPHAGUS/TRACHEA                              1
# LYMPH NODE,  MESENTERIC                        1
# DOSING SITE #1                                 1
# BRAIN, CEREBRUM/BRAIN, CEREBELLUM              1
# HEMOLYMPHORETICULAR SYSTEM (ALL SITES)         1
# Name: MISPEC, Length: 579, dtype: int64
# 3803024

# %%
liver_training_rats = liver[liver.USUBJID.isin(training.USUBJID.values)]

print(liver_training_rats.head())
# Out:
#      STUDYID DOMAIN        USUBJID  MISEQ  ... FOCID MICHRON MIDISTR VISITDY
# 29   8391504     MI  8391504-R0001     30  ...  None    None    None     NaN
# 30   8391504     MI  8391504-R0001     31  ...  None    None    None     NaN
# 57   8391504     MI  8391504-R0002     58  ...  None    None    None     NaN
# 118  8391504     MI  8391504-R0003    119  ...  None    None    None     NaN
# 175  8391504     MI  8391504-R0004    176  ...  None    None    None     NaN
#
# [5 rows x 32 columns]

# %%
liver_training_rats.MISTRESC.value_counts().to_csv('data/RAT/text/training_set_liver_findings.csv')

# %% [markdown]
# ## Results Section 3.3

# %%
def filter_text(x):
    """ returns null if x does not contain a valid numeric response,
    else it extracts that using a regex pattern """
    digit_pattern = r'[-+]?([0-9]*\.[0-9]+|[0-9]+)'
    digit_extract = re.search(digit_pattern, str(x))
    if digit_extract:
        return float(digit_extract.group(0))
    return np.nan

# %%
lb = send_db.generic_query('SELECT * FROM LB')

# %%
lb_training_rats =  lb[lb.USUBJID.isin(training.USUBJID.values)]
lb_training_rats.LBTESTCD = lb_training_rats.LBTESTCD.str.upper()
lb_training_rats.LBSPEC = lb_training_rats.LBSPEC.str.upper()
lb_training_rats.loc[:, 'LBSTRESC'] = lb_training_rats.LBSTRESC.apply(filter_text)
lb_training_rats = lb_training_rats[lb_training_rats.LBSTRESC.notnull()
# Out:
#   File "<ipython-input-118-34faa4eb5769>", line 5
#     lb_training_rats = lb_training_rats[lb_training_rats.LBSTRESC.notnull()
#                                                                            ^
# SyntaxError: unexpected EOF while parsing

# %%
unique_pairs = lb_training_rats[['LBTESTCD', 'LBSPEC']].drop_duplicates()

# %%
no_tests = sum(['-' in test for test in training.columns])

print(f"There are {no_tests} tests in the training set.")

# %%
training
# Out:
#        Unnamed: 0        STUDYID  ... BWSLOPE_NORM  BWINTCEPT_NORM
# 0               0  0436RA140_001  ...     1.046255        1.054913
# 1               1  0436RA140_001  ...     1.092493        1.051529
# 2               2  0436RA140_001  ...     0.861306        0.992232
# 3               3  0436RA140_001  ...     0.727074        0.890487
# 4               4  0436RA140_001  ...     0.801627        1.014396
# ...           ...            ...  ...          ...             ...
# 17280       17280         YV92WD  ...     1.031875        0.943198
# 17281       17281         YV92WD  ...     0.480077        0.888645
# 17282       17282         YV92WD  ...     1.062795        0.974449
# 17283       17283         YV92WD  ...     0.545655        0.848511
# 17284       17284         YV92WD  ...     0.931256        0.981598
#
# [17285 rows x 641 columns]

# %%
# Define species to make a training set
# and make a seperate folder to store
# all the resulting data
import os, numpy as np, math

species = 'RAT'

   
species_data = os.path.join('data', species)
model_folder = os.path.join(species_data, 'models')
prediction_folder = os.path.join(species_data, 'predictions')
    
training_data_file = os.path.join(species_data, f'{species}_training_data.csv')

# %%
min_response_value = 0.4

df = pd.read_csv(training_data_file, index_col=0)
df = df.replace(np.inf, np.nan)
srted_tests = df.notnull().sum().sort_values(ascending=False)

good_tests = df.columns[(df.notnull().sum() / df.shape[0]) > min_response_value]
good_tests = good_tests[~good_tests.isin(['USUBJID', 'STUDYID', 'SEX', 'STEATOSIS',
                                         'CHOLESTASIS', 'NECROSIS', 'SPECIES', 'IS_CONTROL',
                                         'BWDIFF', 'BWSLOPE', 'BWINTCEPT', 'MISTRESC'])]

data = df[good_tests]
data = data.apply(lambda x: x + abs(x.min()) + 1)
data = data.applymap(math.log10)


data.index = df.USUBJID
data['SEX'] = df['SEX']

# %%
tests = []

for t in data.columns:
    
    if '-' in t:
        test, spec = t.split('-')
        
        desc = lb[lb.LBTESTCD == test].LBTEST.value_counts().index[0]
        tests.append([test, spec, desc])
        
    else:
        tests.append([t, 'NA', ''])
tests = pd.DataFrame(tests)
tests.columns = ['Test', 'Tissue', 'Description']
# Out:
# Albumin
# Albumin/Globulin
# Alkaline Phosphatase
# Alanine Aminotransferase
# Activated Partial Thromboplastin Time
# Aspartate Aminotransferase
# Basophils
# Bilirubin
# Calcium
# Cholesterol
# Creatine Kinase
# Chloride
# Creatinine
# Eosinophils
# Fibrinogen
# Gamma Glutamyl Transferase
# Globulin
# Glucose
# Hematocrit
# Hemoglobin
# Potassium
# Large Unstained Cells
# Lymphocytes
# Ery. Mean Corpuscular Hemoglobin
# Ery. Mean Corpuscular HGB Concentration
# Ery. Mean Corpuscular Volume
# Monocytes
# Neutrophils
# pH
# Phosphate
# Platelets
# Protein
# Protein
# Prothrombin Time
# Erythrocytes
# Erythrocytes Distribution Width
# Reticulocytes
# Reticulocytes/Erythrocytes
# Sodium
# Specific Gravity
# Triglycerides
# Urea Nitrogen
# Volume
# Leukocytes

# %%
tests.to_csv('data/RAT/text/tests.csv')

# %%
lb
# Out:
#              STUDYID DOMAIN           USUBJID  ... LBUSCHFL  LBNOMDY LBNOMLBL
# 0            8391504     LB     8391504-R0001  ...     None      NaN     None
# 1            8391504     LB     8391504-R0001  ...     None      NaN     None
# 2            8391504     LB     8391504-R0001  ...     None      NaN     None
# 3            8391504     LB     8391504-R0001  ...     None      NaN     None
# 4            8391504     LB     8391504-R0001  ...     None      NaN     None
# ...              ...    ...               ...  ...      ...      ...      ...
# 11285698  1322-19047     LB  1322-19047-3F060  ...     None      NaN     None
# 11285699  1322-19047     LB  1322-19047-3F060  ...     None      NaN     None
# 11285700  1322-19047     LB  1322-19047-3F060  ...     None      NaN     None
# 11285701  1322-19047     LB  1322-19047-3F060  ...     None      NaN     None
# 11285702  1322-19047     LB  1322-19047-3F060  ...     None      NaN     None
#
# [11285703 rows x 55 columns]

# %%
cl = send_db.generic_query('SELECT * FROM CL')

# %%
cl.CLSTRESC.str.upper().value_counts().index.tolist()
# Out:
# ['NORMAL',
#  'HAIR SPARSE',
#  '0',
#  'ERYTHEMA',
#  'EDEMA',
#  'SKIN AND PELAGE:THINNING HAIR COAT',
#  'FUR, THIN COVER',
#  'THICKENING',
#  'ALOPECIA',
#  'SKIN, RED',
#  'HAIR LOSS',
#  'SKIN - BRUISES',
#  'SCAB',
#  'SKIN AND PELAGE:DISCOLORED HAIRCOAT',
#  'HAIR DISCOLORED',
#  'SKIN DISCOLORED',
#  'SCABBED AREA',
#  'SALIVATION',
#  'EXCRETION:FECES: NORMAL (1.OBSERVATION)',
#  'FECES, SOFT',
#  'SWELLING',
#  'QUALITATIVE FOOD CONSUMPTION:FOOD CONSUMPTION: NORMAL (1.OBSERVATION)',
#  'BRUISE',
#  'SKIN, BRUISE',
#  'MATERIAL AROUND EYES',
#  'SKIN RED',
#  'FECES SOFT',
#  'BRUISING',
#  'SKIN DRY',
#  'FUR THIN',
#  'SKIN, SCAB',
#  'THIN',
#  'FUR STAINED RED',
#  'ABRASION',
#  'SKIN, DRY',
#  'ABNORMAL COLOR',
#  'NO VISIBLE LESIONS:NO VISIBLE LESIONS',
#  'SKIN AND PELAGE:SCAB',
#  'HAIRCOAT, THIN',
#  'ACTIVITY DECREASED',
#  'FUR, STAINING, YELLOW',
#  'SWOLLEN',
#  'FECES WATERY',
#  'HAIR:HAIR LOSS',
#  'THIN COAT',
#  'GOOD',
#  'NODULE',
#  'ABNORMAL URINE COLOR',
#  'ABSENT',
#  'NAD',
#  'EXCRETION:FECES, NONFORMED',
#  'MATERIAL PRESENT',
#  'NORMAL FOOD CONSUMPTION',
#  'BREATHING AUDIBLE',
#  'FECES, LIQUID',
#  'EXCRETION:FECES, LIQUID',
#  'BEHAVIOR:MOUTH RUBBING',
#  'NO EDEMA',
#  'PILOERECTION',
#  'SKIN, DISCOLORED',
#  'EAR/PORTION OF EAR MISSING',
#  'EYE, DISCHARGE',
#  'NO ERYTHEMA',
#  'SKIN AND PELAGE:DISCOLORED SKIN',
#  'REMAINING FOOD 0',
#  'APPEARANCE:SWOLLEN',
#  'FECES, ABNORMAL CONSISTENCY',
#  'NO ABNORMAL SIGNS',
#  'EXCRETION:FECES, DISCOLORED',
#  '100%',
#  'SKIN, PAPULE',
#  'UNREMARKABLE',
#  'SWOLLEN FIRM',
#  'RASH',
#  'EYES:DISCHARGE',
#  'THINNING HAIR COAT',
#  'CRUST PRESENT',
#  'NONE',
#  'SOAP:SOAP 1',
#  'DISCHARGE:EXCESSIVE SALIVATION',
#  'CORNEA, OPACITY, MULTIFOCAL, PINPOINT',
#  'SKIN SCAB',
#  'PELAGE:ABNORMAL COLOR',
#  'ALL FOOD CONSUMED',
#  'SEX SKIN:PRESENT',
#  'FUR, STAINING, RED',
#  'SKIN AND PELAGE:ALOPECIA',
#  'CORNEA, OPACITY, DIFFUSE',
#  'INCREASED URINE EXCRETION',
#  'ABNORMAL STOOL',
#  'DISCHARGE',
#  'SKIN AND PELAGE:SORE',
#  'HAIR:STAINED',
#  'LETHARGY (HYPOACTIVE) WITH SLEEPINESS',
#  'OEDEMA / SWELLING',
#  'SEXUAL SKIN',
#  'ABRASION(S)',
#  'LACRIMATION',
#  'SHORT TAIL',
#  'HUNCHED POSTURE',
#  'TAIL BENT',
#  'CORNEA OPACITY',
#  'SKIN, BLACK',
#  'EXCRETION:SALIVATION',
#  'SCAB/CRUST',
#  'SCABS',
#  'FOOD CONSUMPTION:SATISFACTORY – LESS THAN OR EQUAL TO 2/3 REMAINING',
#  'EYELID(S)-PARTIALLY CLOSED',
#  'SKIN AND FUR:THINNING FUR',
#  'DISCOLORATION',
#  'SKIN, ABRASION',
#  'CHANGED FECES CONSISTENCY',
#  'FECES LOOSE W/OUT NORMAL FECES',
#  'TREMORS',
#  'NO ABNORMALITY DETECTED',
#  'SKIN, LESION',
#  'FUR, WET',
#  'VOMITUS',
#  '',
#  'ESCHAR FORMATION:NO',
#  'DESQUAMATION:0: NO DESQUAMATION',
#  'FISSURES:0: NONE',
#  'ULCER:NO',
#  'APPEARANCE:THIN',
#  '50 PERCENT TO MOST CONSUMED',
#  'APPEARANCE:RED',
#  'QUALITATIVE FOOD CONSUMPTION:LOW',
#  'EXCRETION:FECES',
#  'ERYTHEMA:0: NO ERYTHEMA',
#  'SOFT STOOL',
#  'HAIR-LOSS',
#  'SKIN BROWN',
#  'FECES DISCOLORED',
#  'LEFT EYE:NO VISIBLE LESIONS',
#  'TEETH, BROWN',
#  'EXTERNAL GENITAL BLEEDING',
#  'SKIN AND PELAGE:SCALY SKIN',
#  'OTHER (SEE COMMENT)',
#  'SWELLING SOFT',
#  'LIMITED USAGE',
#  'FUR WET',
#  'SWOLLEN SOFT',
#  'EYE, PARTLY CLOSED',
#  'FUR, ERECTED',
#  'VULVA, DISCHARGE LIQUID',
#  '100',
#  'FUR, STAINING',
#  'SOILED',
#  'EDEMA:0: NO EDEMA',
#  'LOOSE STOOLS',
#  '>70% OF THE FOOD GIVEN WAS CONSUMED',
#  'RIGHT EYE:NO VISIBLE LESIONS',
#  'EXCRETA',
#  'MATERIAL IN PAN/BEDDING',
#  'PRESENT',
#  'OCULAR DISCHARGE',
#  'COAT SOILED',
#  'MENSTRUATION',
#  'TAIL MISSING - PORTION',
#  'FUR, OILY',
#  'POSTURE HUNCHED',
#  'DIARRHEA',
#  'LOSS OF FUR',
#  'SPARSE HAIR',
#  'SKIN AND FUR SIGNS:ALOPECIA',
#  'FUR STAINED',
#  'FECES LOOSE',
#  'FECES MUCOID',
#  'INAPPETENCE',
#  'DISCOLORATION, BLEEDING SITE',
#  'HAIRCOAT STAINED RED',
#  'PLOUGHING',
#  'REDUCED APPETITE',
#  'NO FINDING',
#  'DISCHARGE, BROWN',
#  'DISCHARGE:VOMITUS',
#  'DEHYDRATED SUSPECTED',
#  'FUR, STAINING, BROWN',
#  'INJECTION SITE:SWOLLEN',
#  '5: ALL FOOD CONSUMED',
#  'EXCESSIVE LICKING',
#  'SKIN AND FUR:SORES/LESIONS',
#  'LENS OPACITY, NUCLEUS',
#  'LESION(S)',
#  'UNKEMPT APPEARANCE',
#  'MATERIAL AROUND NOSE',
#  'FECES LOOSE  (GROUP HOUSED)',
#  'NORMAL CONSUMPTION',
#  'EYELID PARTIALLY/COMPLETELY CLOSED',
#  'GU,   URINE DISCOLORED',
#  'CORNEA, OPACITY',
#  'WOUND',
#  '4: 50 PERCENT TO MOST CONSUMED',
#  'MASS',
#  'BODY CONDITION (HALF SCORE)',
#  'VULVA ENLARGED',
#  'ABNORMAL GAIT',
#  'EYE DISCOLORED',
#  'HAIRLESS AREA',
#  'SECRETION:DISCHARGE',
#  'UNKEMPT',
#  'HOUSING:SUPPLEMENT FOOD',
#  'FUR, LOSS',
#  'EYEBALL, RED',
#  'VOMITING',
#  'TAIL:NORMAL',
#  'RUFFLED',
#  'SKIN, FLAKING',
#  'SKIN:ABNORMAL COLOR',
#  '100 CO',
#  'ABDOMINAL DISTENTION',
#  'THINNING OF HAIR',
#  'EYES:TEARS',
#  'FECES, UNFORMED-CAGE-UNIT',
#  'SCAB(S)',
#  'APPEARS NORMAL',
#  'POST DOSING STATUS:NORMAL',
#  'SCAR',
#  'REDNESS',
#  'CRUST FORMATION',
#  'SKIN AND FUR:RAISED HAIR',
#  'TEETH DISCOLORED',
#  'VULVA, DILATED',
#  'FECES',
#  'CORNEA, OPACITY, PINPOINT',
#  'TESTIS:SIZE ABNORMALITY',
#  'SKIN ABNORMALITY - ALOPECIA',
#  'SKIN STAINING',
#  'EMESIS',
#  'HAND HELD OBSERVATIONS:APPEARANCE OF FUR',
#  'ELICITED BEHAVIORS:PUPILLARY STATUS',
#  'ELICITED BEHAVIORS:CORNEAL RESPONSE',
#  'ELICITED BEHAVIORS:PROPRIOCEPTIVE POSITIONING',
#  'ELICITED BEHAVIORS:PUPILLARY RESPONSE',
#  'HAND HELD OBSERVATIONS:PALPEBRAL CLOSURE (PTOSIS)',
#  'NOT SUPPLY',
#  'HOME CAGE OBSERVATIONS:GAIT ABNORMALITIES',
#  'HAND HELD OBSERVATIONS:REACTIVITY TO HANDLING',
#  'HAND HELD OBSERVATIONS:EXOPHTHALMOS',
#  'OPEN FIELD OBSERVATIONS:POSTURE - ARENA',
#  'ELICITED BEHAVIORS:PINNA RESPONSE',
#  'ELICITED BEHAVIORS:AUDITORY REACTIVITY',
#  'HAND HELD OBSERVATIONS:PILOERECTION',
#  'OPEN FIELD OBSERVATIONS:LOCOMOTOR ACTIVITY - ARENA',
#  'OPEN FIELD OBSERVATIONS:GAIT ABNORMALITIES - ARENA',
#  'HAND HELD OBSERVATIONS:MUSCLE TONE',
#  'HAND HELD OBSERVATIONS:PUPILLARY STATUS',
#  'HAND HELD OBSERVATIONS:VOCALIZATION',
#  'HOME CAGE OBSERVATIONS:OTHER UNUSUAL BEHAVIOR',
#  'HAND HELD OBSERVATIONS:RESPIRATION',
#  'HAND HELD OBSERVATIONS:EXCESSIVE LACRIMATION',
#  'ELICITED BEHAVIORS:NOCICEPTIVE RESPONSE',
#  'OPEN FIELD OBSERVATIONS:OTHER UNUSUAL BEHAVIOR - ARENA',
#  'HOME CAGE OBSERVATIONS:ACTIVITY',
#  'ELICITED BEHAVIORS:APPROACH RESPONSE',
#  'HOME CAGE OBSERVATIONS:POSTURE',
#  'HAND HELD OBSERVATIONS:EXCESSIVE SALIVATION',
#  'ELICITED BEHAVIORS:RIGHTING REFLEX',
#  'DECREASED ACTIVITY',
#  'SOFT',
#  'INJECTION SITE, THICKENED',
#  'FECAL SMEARING',
#  'ACTIVITY INCREASED',
#  'ACTIVITY INCREASED(BEH)',
#  'SCLERA INJECTED',
#  'VAGINA, DISCHARGE LIQUID',
#  'ULCER PLANTAR/PALMAR',
#  'FOOD SEMI-QUANTITATIVE 100%',
#  'EMESIS AFTER DOSING',
#  'EAT ALL',
#  'RIGHT EYE:VITREOUS CELL',
#  'ABNORMAL APPEARANCE OF FAECES',
#  'FLAKY SKIN',
#  'CORNEAL OPACITY',
#  'INCREASE IN SIZE',
#  'ESCHAR',
#  'MATERIAL, FOAMY, WHITE',
#  'SKIN COLD TO TOUCH',
#  'FECES LOOSE W/OUT NORMAL FECES, SMALL AMOUNT',
#  'CATARACT',
#  'VOMIT',
#  'CORNEA:DYSTROPHY',
#  'GI - SALIVATION',
#  'WHITISH CHANGE OF TEETH',
#  'WHISKERS MISSING',
#  'DISCHARGE:ORAL',
#  'EMESIS NOT PRESENT',
#  'FAECES - GROUP HOUSED',
#  'ULCERATION',
#  'APPEARANCE:BODY CONDITION SCORING',
#  'FECES, W/ MUCOID MATERIAL',
#  'SUPERFICIAL PUNCTATE KERATOPATHY',
#  'AGGRESSION TO CAGE MATE:NORMAL',
#  'GAIT:NORMAL',
#  'BEHAVIOR - STEREOTYPE:NORMAL',
#  'INVOLUNTARY MOVEMENTS:NORMAL',
#  'BEHAVIOR - OTHER:NORMAL',
#  'POSTURE:NORMAL',
#  'MATERIAL, LIQUID, BROWN',
#  'ALERTNESS:NORMAL',
#  'FUR STAINED YELLOW',
#  'RETINA, FOLD',
#  'DISCHARGE, YELLOW',
#  'VOCALIZATION',
#  'NORMAL INTAKE',
#  'KINKED TAIL',
#  'FECES SOFT  (GROUP HOUSED)',
#  '40%-70% OF THE FOOD GIVEN WAS CONSUMED',
#  'ACTIVITY:NORMAL',
#  'BACKBONE PROMINENT',
#  'SCRATCH',
#  'EROSION',
#  'BEHAVIOR:ACTIVITY DECREASED',
#  'NO',
#  'SKIN AND PELAGE:ROUGH HAIRCOAT',
#  'QUALITATIVE FOOD CONSUMPTION:FASTING OVERNIGHT',
#  'SKIN AND PELAGE:BROKEN SKIN',
#  'SENSITIVE TO TOUCH',
#  'FECES, LIQUID-CAGE-UNIT',
#  'COAT-PILOERECT',
#  'HAIR THINNING',
#  'SCURF',
#  'S.C.-INJECTION SITE/S:NORMAL',
#  'APPEARANCE:BRUISING',
#  'DRY',
#  'FAIR',
#  'SCAB, FOCAL',
#  'NORMAL IRIS WITHOUT ANY HYPEREMIA OF THE IRIS VESSELS',
#  'APPARENT ESTRUS',
#  'SKIN, PALE',
#  'APPETITE DECREASED',
#  'BLACKISH BROWN SPOT',
#  'EXCRETION:FECES: DISCOLORED (1.OBSERVATION)',
#  'YES',
#  'ABDOMINAL DISTENSION',
#  'HYPERSALIVATION',
#  'FOOD CONSUMPTION:SATISFACTORY ? LESS THAN OR EQUAL TO 2/3 REMAINING',
#  'SKIN AND PELAGE:PILOERECTION',
#  'HEAD TILT',
#  'HANDLING PUPIL SIZE - RIGHT EYE',
#  'HANDLING PUPIL SIZE - LEFT EYE',
#  'HANDLING EYE PROMINENCE - RIGHT EYE',
#  'TAIL, BENT',
#  'HANDLING EYE PROMINENCE - LEFT EYE',
#  'DAMAGED EYE',
#  'POSTURE',
#  'NORMAL, NO DISCHARGE',
#  'NORMAL OR NO SWELLING OF THE CONJUNCTIVAL TISSUE',
#  'NO PANNUS',
#  'NORMAL PUPIL RESPONSE',
#  'ARENA STEREOTYPICAL OR BIZARRE BEHAVIOR',
#  'ARENA POSTURE',
#  'HANDLING LACRIMATION',
#  'HANDLING EXTENSOR THRUST',
#  'HANDLING OVERALL REACTIVITY',
#  'ARENA TREMOR WHOLE BODY',
#  'ARENA PILOERECTION',
#  'HANDLING TACTILE REFLEX',
#  'ARENA TREMOR HEAD',
#  'ARENA GROOMING',
#  'ARENA TONIC SPASMS OR CONVULSIONS',
#  'HANDLING TAIL PINCH',
#  'HANDLING PUPILLARY RESPONSE - RIGHT EYE',
#  'ARENA TREMOR LIMBS',
#  'HOME CAGE TONIC SPASMS OR CONVULSIONS',
#  'TREMOR LIMBS',
#  'HANDLING SALIVATION',
#  'TREMOR HEAD',
#  'HANDLING RESPIRATORY RATE',
#  'ARENA ALERTNESS',
#  'REMOVAL',
#  'HANDLING AURICULAR STARTLE',
#  'ARENA PALPEBRAL CLOSURE - LEFT EYE',
#  'ARENA PALPEBRAL CLOSURE - RIGHT EYE',
#  'HANDLING RESPIRATORY PATTERN',
#  'HOME CAGE TREMOR WHOLE BODY',
#  'ANNULAR CONSTRICTION',
#  'HANDLING PINNA REFLEX - LEFT PINNA',
#  'ARENA URINATION',
#  'ARENA GAIT',
#  'HANDLING BODY TONE',
#  'HANDLING PUPILLARY RESPONSE - LEFT EYE',
#  'STEREOTYPICAL OR BIZZARE BEHAVIOR',
#  'ARENA DEFECATION',
#  'SKIN:DISCOLORED',
#  'TAIL, MISSING',
#  'HANDLING PINNA REFLEX - RIGHT PINNA',
#  'UNCOORDINATED',
#  'DISCHARGE, COLOR',
#  'BREATHING, ABNORMAL SOUNDS',
#  'HAIR:PILO-ERECTION',
#  'DEFORMITY',
#  '75%',
#  'INCREASED SALIVATION AFTER ADMINISTRATION',
#  'FECES CONSISTENCY ALTERED',
#  'DULL FUR',
#  'HYPERSENSITIVE',
#  'SKIN DISCOLORATION',
#  'DISCHARGE:APPEARS TO BE MENSTRUATING',
#  'GI,   FECES SOFT',
#  'HAIR LOSS, THORAX, VENTRAL (DUE TO JACKET), SLIGHT',
#  'HAIR LOSS, AXILLARY, RIGHT (DUE TO JACKET), SLIGHT',
#  'HAIR LOSS, AXILLARY, LEFT (DUE TO JACKET), SLIGHT',
#  'SKIN AND FUR:STAINING',
#  'GENERAL APPEARANCE AND CONDITION:TAIL CROOKED',
#  'ANIMAL ATE ALL OF ITS FOOD',
#  'LOOSE STOOL',
#  'SCAB, MULTIFOCAL',
#  'MALOCCLUSION',
#  'FECES, WHITE',
#  'WEAK',
#  'BEHAVIOR:HYPOACTIVE',
#  'PINNA PARTLY MISSING',
#  'BRUISE INNER THIGH(S)',
#  'UNSCHEDULED DEATH REASON:GENERAL DEBILITATION',
#  'CRUST',
#  'HARD PROTRUSION',
#  'GAIT/POSTURE:HUNCHED POSTURE',
#  'PROSTRATE',
#  'OPACITY',
#  'APPEARANCE:MISSING',
#  'TRAUMA',
#  'EXCRETION:FECES, MUCOID',
#  'SKIN SCALING',
#  'PELAGE:THINNING',
#  'FECES, PALE',
#  'WHITENING OF TEETH',
#  'LOOSE FECES',
#  'EXCRETION:NORMAL',
#  'STAINING',
#  'SURFACE AIR RIGHTING REFLEX',
#  'DISCHARGE - UNKNOWN SOURCE:FOUND IN PAN',
#  'FOOD PARTLY DIGESTED',
#  '1',
#  'BEHAVIOR:EMESIS',
#  'LACERATION',
#  'SKIN THICKENED',
#  'TOENAIL MISSING',
#  'EYES:SQUINTING',
#  'INTACT',
#  'INJECTION/DERMAL SITE:SAPHENOUS VEIN',
#  'PELAGE:NORMAL',
#  'PUPIL STATUS:NORMAL',
#  'GRASPING LOSS:NORMAL',
#  'PINNA RESPONSE:NORMAL',
#  'PAIN RESPONSE:NORMAL',
#  'EXTENSOR THRUST:NORMAL',
#  'RIGHTING REFLEX:NORMAL',
#  'RESTLESSNESS:NORMAL',
#  'LACRIMATION:NORMAL',
#  'RESPIRATION:NORMAL',
#  'BODY TONE:NORMAL',
#  'PROPRIOCEPTION (RIGHT HIND LEG):NORMAL',
#  'VISUAL RESPONSE:NORMAL',
#  'EYE CLOSURE:NORMAL',
#  'SALIVATION:NORMAL',
#  'PALPEBRAL REFLEX:NORMAL',
#  'WAXY RIGIDITY:NORMAL',
#  'BAR TEST:NORMAL',
#  'GRIP STRENGTH:NORMAL',
#  'EYES:NORMAL',
#  'INTERDIGITAL CYST',
#  'ASSESSMENT:BRIGHT, ALERT, AND RESPONSIVE',
#  'PUPILLARY RESPONSE:NORMAL',
#  'REACTIVITY TO HANDLING:NORMAL',
#  'SOME EATEN',
#  'FECES, SOFT FECES',
#  'DISCHARGE:NORMAL',
#  'NEGATIVE',
#  'CRACKED FOOT PAD',
#  'SKIN AND PELAGE:DRY SKIN',
#  'ALOPECIA OBSERVED BY BEHAVIOR SPEC',
#  'DISCOLORED HAIRCOAT',
#  'FUR DULL',
#  'VOMITED',
#  'AUDITORY STARTLE RESPONSE:NORMAL',
#  'SWOLLEN (CAGESIDE)',
#  'APPROACH RESPONSE:NORMAL',
#  'FUR, UNGROOMED',
#  'SKIN COLOR:NORMAL',
#  'DISTENDED ABDOMEN',
#  'VOCALIZATION:NORMAL',
#  'EXCRETION:FECES: SOFT FECES (1.OBSERVATION)',
#  'BEHAVIOR:STRUGGLED DURING DOSING',
#  'MATERIAL, DRY, RED',
#  'SKIN WARM TO TOUCH',
#  'TRUNK:LESION/S',
#  'VAGINAL DISCHARGE',
#  'CHROMODACRYORRHEA',
#  'ANIMAL FASTED',
#  'APPEARANCE:BENT TAIL',
#  'GENERAL:THIN APPEARANCE',
#  'MASS 1',
#  'APPEARANCE:EFFECT OF ANESTHESIA',
#  'HYPOACTIVITY',
#  'SKIN AND FUR SIGNS:SCAB',
#  'COLD TO TOUCH',
#  'PIGMENTATION',
#  'NORMAL NO REDDISH PINK',
#  'HAIR WET',
#  'NO ABNORMALITIES DETECTED',
#  'SWELLING, SURGICAL SITE, INGUINAL RIGHT, SLIGHT',
#  'SKIN AND PELAGE:RAISED AREA',
#  'INJECTION/DERMAL SITE:SUBCUTANEOUS',
#  'SKIN WOUND',
#  'LOCOMOTORY STEREOTYPY',
#  'COLOR CHANGE',
#  'SKIN, PURPLE',
#  'FECES LIQUID',
#  'DISCHARGE:APPEARS TO BE CYCLING',
#  'FLUSH',
#  'SKIN:SCAB(S)',
#  'OVERGROWN TEETH',
#  'APPEARANCE:HUNCHED',
#  '0%',
#  'HUNCHED',
#  'ABNORMAL SKIN COLOR',
#  'LAST SITE DOSED:SAPHENOUS VEIN',
#  'LOSS OF SKIN ELASTICITY',
#  'SORE',
#  'MUCUS STOOL',
#  'SALIVATION:INCREASED',
#  'RAPID HEART RATE',
#  'EXCRETION:NON-FORMED FECES',
#  'SKIN DISCOLORATION, RED, AXILLARY, RIGHT (DUE TO JACKET)',
#  'APPEARANCE:WARM TO TOUCH',
#  'EMESIS:POST-DOSE',
#  'SKIN:ABRASION',
#  'FECES, LOOSE FECES',
#  'SKIN:SCAB',
#  'CORNEA:CORNEAL DYSTROPHY',
#  'GH FECES',
#  'GAIT, FLAT FOOTED',
#  'EYEBALL, ABNORMAL COLOR',
#  'FUR ERECTED',
#  'LENS OPACITY - NUCLEUS',
#  'NODOSITIES',
#  'TOOTH MISSING',
#  'SKIN LESION WET SORE',
#  'LEFT EYE:VITREOUS CELL',
#  'ASSESSMENT:SKIN ELASTICITY',
#  'ATAXIA',
#  'EXTREMITY/IES:LESION/S',
#  'VETERINARY CARE',
#  '.PERIVENOUS HEMORRHAGIC INFILTRATION',
#  'OEDEMA:0: NO OEDEMA',
#  'SEX SKIN SWELLING',
#  '75 CO',
#  'FUR - REDUCED HAIR DENSITY',
#  'LOSS OF LIMB FUNCTION',
#  'LENS OPACITY, CAPSULE, POSTERIOR',
#  'TEETH, BROKEN',
#  'MATERIAL FROTHY WHITE',
#  'MATERIAL, LIQUID, RED',
#  'EYE CLOSED',
#  'SKIN AND FUR:HAIR LOSS',
#  'RED DISCOLORATION AROUND EYES',
#  'SOLID FEED SUP/PELLET MIX',
#  'NAIL MISSING',
#  'ANOGENITAL-STAINING AROUND',
#  'BODY RIGID',
#  'HYPERSENSITIVE TO TOUCH',
#  'SKIN DISCOLORATION, RED, AXILLARY, LEFT (DUE TO JACKET)',
#  'REDUCED FECAL OUTPUT',
#  'SOFT FECES',
#  'ABDOMEN DISTENDED',
#  'LENS OPACITY',
#  'LIMB FUNCTION IMPAIRED',
#  'DECREASED SPONTANEOUS MOTOR ACTIVITY',
#  'OBSERVED',
#  'FOOD CONSUMPTION:SATISFACTORY LESS THAN OR EQUAL TO 2/3 REMAINING',
#  'MASS PRESENT',
#  'MACROSCOPIC EYE EXAMINATION:NO FINDING',
#  'UNFORMED STOOL',
#  'MOULTING',
#  'BROKEN NAIL/CLAW',
#  'INCREASED SALIVATION',
#  'IRIS, PERSISTENT PUPILLARY MEMBRANE',
#  'EYE, PUPIL DILATED',
#  'SKIN:SWELLING',
#  'SKIN DISCOLORATION, RED, NECK AREA (DUE TO JACKET)',
#  'LESION',
#  'DIGIT MISSING',
#  'PERSISTENT HYALOID ARTERY',
#  'THIN, SLIGHT',
#  'EYES:DILATED PUPIL',
#  'FOOD SEMI-QUANTITATIVE 50%',
#  'HAIRLOSS',
#  'SKIN, LESION W/ DISCHARGE',
#  'EXFOLIATION',
#  'SKIN, BLUE',
#  'TAIL:MISSING',
#  'LUMP',
#  'LOW CARRIAGE',
#  'SLIGHT SOILED UROGENITAL REGION',
#  '2',
#  'SOAP:SOAP 2',
#  'EXCRETION:DISCHARGE',
#  'THINNING OF FUR',
#  'BEHAVIOR/APPEARANCE:THIN',
#  'LAMENESS',
#  'FUR - ALOPECIA',
#  'LAST SITE DOSED:SUBCUTANEOUS',
#  'FOOD CONSUMED:ALL',
#  'THIN APPEARANCE',
#  'RESPIRATION, NOISY RESPIRATION',
#  'GUMS DISCOLORED',
#  'EROSION, MUCOSA',
#  'SKIN, PINK',
#  'APPEARANCE:DAMAGED',
#  'BEHAVIOUR - ACTIVITY',
#  'DIGIT COMPLETE/PORTION MISSING',
#  'ENCRUSTATION',
#  'MUSCLE TONE',
#  'FECES LOOSE W/OUT NORMAL FECES, MODERATE AMOUNT',
#  'FUR - HAIR LOSS',
#  'SLIT LAMP EXAMINATION:NO FINDING',
#  'APPEARANCE:LIMITED USE',
#  'PINK',
#  'CORNEAL DYSTROPHY',
#  'CALCULUS',
#  'PROSTRATION',
#  'NO ABNORMAL CHANGES',
#  'EYE OPACITY',
#  'OTHER:SUBSTANCE IN PAN',
#  'LETHARGY',
#  'NASAL DISCHARGE',
#  'CIRCLING',
#  'EYES:OPAQUE',
#  'ABNORMAL SPONTANEOUS MOTOR ACTIVITY',
#  'HAIR, STAINED',
#  'DECREASED MOTOR ACTIVITY',
#  'RESPIRATORY RATE INCREASED',
#  'NORMAL TEMPERATURE AND RESPIRATION/MIN',
#  'INJECTION SITE:SCAB(S)',
#  'SUPERFICIAL, PUNCTATE, KERATOPATHY',
#  'ROOTING IN THE BEDDING MAT.',
#  'EYE FUNDUS:NO FINDING',
#  'DISCHARGE, RED',
#  'SKIN:SMALL SUPERFICIAL BUMPS',
#  'SUBDUED',
#  'NORMAL WITH COAT SMOOTH, EYES/NOSE CLEAR',
#  'GENITAL AND RECTAL SIGNS:DISCHARGE',
#  'SKIN LESION SCAB',
#  'REDDENING AT GROIN',
#  'OTIC DEBRIS',
#  'PUPIL CONSTRICTED',
#  'SKIN:SCURF',
#  'BITE WOUND',
#  'SKIN ABNORMALITY - ABRASION',
#  'DOSE SITE ABNORMAL-OTHERS',
#  'HEMATOMA',
#  'MALE',
#  'TAIL KINKED',
#  'SWELLING FIRM',
#  'OVERALL SEVERITY',
#  'FEMALE',
#  'ORANGE COLOURATION AT GROIN',
#  'N/A',
#  'AGGRESSIVE',
#  'APPEARANCE:MALOCCLUSION',
#  'FECES, OUTPUT DECREASED',
#  'APPEARANCE, SWOLLEN, URO-GENITAL AREA',
#  'REFER TO COMMENTS',
#  'COAT, HAIR LOSS',
#  'HYPERREACTIVE',
#  'MISSING',
#  'FECES, RED',
#  'MATERIAL DRY RED  (GROUP HOUSED)',
#  'INJECTION SITE:SCARS',
#  'FECES FEW/ABSENT',
#  'EXCRETION, NORMAL',
#  'BEHAVIOR:STRUGGLED DURING IOP TRAINING',
#  'REDNESS AND BLANCHING',
#  'MUSCLE TONE:0: NORMAL',
#  'GRIP STRENGTH:0: NORMAL',
#  'BALANCE/ COORDINATION:0: NORMAL',
#  'EXCRETION:FECES: LIQUID FECES (1.OBSERVATION)',
#  'REACTION TO ACOUSTIC STIMULI:0: NORMAL',
#  'DISCHARGE, WHITE',
#  'TREMOR:0: ABSENT',
#  'INJECTION SITE, RED STAINED',
#  'STIFF LIMBS',
#  'CHEWING ACTION',
#  'FECES:UNFORMED',
#  'CHECKING VOCALIZATION:0: NORMAL',
#  'STEREOTYPY:0: ABSENT',
#  'EXCRETION:DISCOLORED FECES',
#  'RAPID BREATHING',
#  'DOSE SITE:INJECTION/DERMAL SITE',
#  'RUFFLED FUR',
#  'AGGRESSION (DEFENSIVE):0: ABSENT',
#  'IN SEASON DISCHARGE',
#  'COMMUNICATIVE VOCALIZATION:0: NORMAL',
#  'DISCHARGE:RED',
#  'ALERTNESS:0: NORMAL',
#  'MATERIAL, MUCOID, RED',
#  'STRUGGLING DURING DOSING',
#  'DOSE SITE ABNORMAL-DESQUAMATION',
#  'EMACIATION',
#  'HAIR LOSS, NECK AREA (DUE TO JACKET), SLIGHT',
#  'SKIN, PALLOR',
#  'INCREASED',
#  'HYALOID REMNANT',
#  'LOCOMOTOR ACTIVITY:0: NORMAL',
#  'CRUST PRESENT, PINNA, RIGHT, SLIGHT',
#  'EYE DISCHARGE',
#  'PTYALISM',
#  'HEAD:LESION/S',
#  'FECES LIQUID W/OUT NORMAL FECES',
#  'GI URO STOOL SOFT',
#  'UNSCHEDULED DEATH REASON:FOUND DEAD',
#  'EXCRETION:LIQUID FECES',
#  'FUR,  STAINED',
#  'MATERIAL, MUCOID, BROWN',
#  'LACERATION(S)',
#  'SWOLLEN AREA',
#  'RIGHT EYE - NO VISIBLE LESIONS:NO VISIBLE LESIONS',
#  'HUNCHED BACK',
#  'PINNA, MISSING (PT)',
#  'LEFT EYE - NO VISIBLE LESIONS:NO VISIBLE LESIONS',
#  'PALE',
#  'RALES',
#  'SKIN TURGOR SLOW',
#  'SKIN - CRUST',
#  'BLUNTED TAIL',
#  'BEHAVIOR:ATAXIC',
#  'CONJUNCTIVA:DISCHARGE (0-3)',
#  'ULCER',
#  'ASSESSMENT:MUCOUS MEMBRANE COLOR',
#  'SALIVATION (OUT OF NORMAL)',
#  'AGGRESSION (OFFENSIVE):0: ABSENT',
#  'ESTRUS',
#  'DOSE SITE ABNORMAL-EDEMA',
#  'RAISED AREA',
#  'MATERIAL, LIQUID, WHITE',
#  'FUR,  HAIR LOSS',
#  'WHITENING OF THE TEETH',
#  'ERYTHEMA WITH SEVERITY',
#  'BEHAVIOR/APPEARANCE:FUR ABNORMALITIES: HAIR LOSS, LARGE AREA',
#  'RESPIRATORY RATE ABNORMAL',
#  'LENS OPACITY, CORTEX, ANTERIOR, FOCAL',
#  'ERYTHEMA.',
#  'EXCESSIVE TARTAR',
#  'SALIVATION INCREASED',
#  'LYING ON SIDE',
#  'DISCHARGE OD',
#  'GENERAL:MUCUS MEMBRANE, CAPILLARY REFILL TIME',
#  'REDNESS (CONGESTION) OS',
#  'SWELLING (CHEMOSIS) OD',
#  'FAVORING (LIMB)',
#  'SWELLING (CHEMOSIS) OS',
#  'FECES LIQUID  (GROUP HOUSED)',
#  'DISCHARGE OS',
#  'SKIN AND PELAGE:SCAR',
#  'REDNESS (CONGESTION) OD',
#  'MENSES',
#  'SKIN:SCRATCH / LACERATION',
#  'DISCHARGE, CONSISTENCY',
#  'MATERIAL, LIQUID, YELLOW',
#  'EXCRETION:FECES, NORMAL',
#  'LESION(S), AXILLARY, LEFT (DUE TO JACKET), SLIGHT',
#  'VOMITUS, LIQUID, WHITE',
#  'RAPID',
#  'CORNEA, OPACITY, LINEAR',
#  'TAIL DEVIATION',
#  'LYING ON CAGE FLOOR',
#  'KERATOPATHY, PUNCTATE, SUPERFICIAL',
#  'DISCOLORED',
#  'GENERAL, MASS',
#  'INCREASED ACTIVITY',
#  'TEETH, WHITE',
#  'CRUST PRESENT, AXILLARY, LEFT (DUE TO JACKET), SLIGHT',
#  'OTHER',
#  'EXFOLIATION WITH SEVERITY',
#  'VOCALIZATION INCREASED',
#  'EYE(S)-MATERIAL AROUND',
#  'ESCHAROSIS',
#  'SLIT LAMP EXAMINATION:OPACITY',
#  'ORAL CAVITY SIGNS:SALIVATION',
#  'APPEARANCE:MASS',
#  'SKIN, SWELLING',
#  'EYE-PALE',
#  'SWELLING-FOCAL',
#  'CRUST PRESENT, SURGICAL SITE, DORSAL, SLIGHT',
#  'EYES:CONJUNCTIVA, PALPEBRAL',
#  'EMESIS NOT PRESENT, NO CAPSULE PRESENT, NO REDOSE',
#  'FOOD CONSUMPTION DECREASE',
#  'BEHAVIOR:VOCALIZATION',
#  'BREATHING, LABORED',
#  'FECES, BLACK',
#  'MATERIAL, DRY, WHITE',
#  'RETINA/CHOROID, PIGMENTATION, IRREGULAR',
#  'SCABBING',
#  'TEETH BROKEN',
#  'REMAINING FOOD 1/4',
#  'LESION(S), AXILLARY, RIGHT (DUE TO JACKET), SLIGHT',
#  'LATERAL RECUMBENCY',
#  'ABDOMINAL FIRM INTERNAL STRUCTURE',
#  'SWELLING, PINNA, RIGHT, SLIGHT',
#  'ANIMAL ON HEAT',
#  'NO SIGNIFICANT LESIONS',
#  'MAY APPEAR BLANCHED TO REDDISH WITHOUT PERILIMBAL INJECTION',
#  'OPTIMUM',
#  'ABRASION, DRY',
#  'LIQUID FAECES',
#  'SKIN LUMP',
#  'REDDENING AT SAMPLING SITE',
#  'OTHER SYMPTOM SEE COMMENT',
#  'LOUD BREATHING',
#  'WATERY STOOL',
#  'SKIN - ABRASION',
#  'MASSES',
#  'EXCRETA, WATERY STOOL',
#  'BREATHING, LABORED(BEH)',
#  'DECREASED FOOD CONSUMPTION',
#  'DISCHARGE, CLEAR',
#  'VOMITUS:CONTAINING FOOD',
#  'NIPPLE ENLARGEMENT',
#  'EROSION, SKIN',
#  'GI - REDUCED APPETITE',
#  'CRACKLES',
#  'LENS OPACITY, NUCLEUS, FOCAL',
#  'ANIMAL HEALTH:CHECK VISIT',
#  'GENERAL APPEARANCE AND CONDITION:MISSING',
#  'QUALITATIVE FOOD CONSUMPTION:FOOD CONSUMPTION: LOW (1.OBSERVATION)',
#  'CORNEA, OPACITY, FOCAL',
#  'APPETITE DECREASED  (GROUP HOUSED)',
#  'SOILED FUR',
#  'DOSE SITE:LAST SITE DOSED',
#  'SKIN, BROWN',
#  'EYES:CONSTRICTED PUPIL',
#  'REDDENING AT TREATMENT SITE',
#  'STEREOTYPY',
#  'BENT TAIL',
#  'RED DISCOLOURED SKIN - SPOT',
#  'ADMIXTURE IN FECES',
#  'FAECES - SINGLE HOUSED',
#  'SWELLING, NECK AREA (DUE TO JACKET), SLIGHT',
#  'GI,   FECES LIQUID',
#  'ASSESSMENT:RESPIRATION, QUALITATIVE',
#  'MATERIAL, MUCOID, YELLOW',
#  'QUALITATIVE FOOD CONSUMPTION:NONE',
#  'UNSCHEDULED DEATH REASON:SIZE AND/OR APPEARANCE OF MASS',
#  'NO DISCHARGE',
#  'CRUST PRESENT, AXILLARY, RIGHT (DUE TO JACKET), SLIGHT',
#  'CRUST, SKIN',
#  'LIQUID FAECES (GRP)',
#  'PALLOR',
#  'FUR, STAINING, ORANGE',
#  'MUSCLE CRAMPING:0: ABSENT',
#  'POSTURE (BODY/HEAD):0: NORMAL',
#  'REACTION TO VISUAL STIMULI:0: NORMAL',
#  'TWITCHES/JERKS:0: ABSENT',
#  'GI,   SALIVATION',
#  'LACRIMATION:0: ABSENT',
#  'SALIVATION:0: ABSENT',
#  'SIGNS OF ESTRUS',
#  'GROOMING:0: NORMAL',
#  'EYES:PROTRUDING',
#  'FECES, ABNORMAL COLOR',
#  'FECES, DARK',
#  'CARRIAGE LOW',
#  'SKIN WOUND WITH DISCHARGE',
#  'CORNEA, PUNCTATE OPACITY',
#  'DEPOSITS',
#  'SKIN - WOUND, DRY',
#  'HYPEREMIA MUCOUS MEMBRANES',
#  'ABDOMINAL BREATHING',
#  'SCANT FECES',
#  'HAIR:THIN',
#  'LIQUID FAECES.',
#  'BODY CONDITION (SCALE I-V)',
#  'MINOR CHANGES/LESS INTERACTION WITH STAFF',
#  'CRUST PRESENT, FORELIMB, RIGHT, SLIGHT',
#  'MATERIAL, DRY, BROWN',
#  'BODY SURFACE COLD',
#  'FECES, GREEN',
#  'MATERIAL MUCOID BROWN  (GROUP HOUSED)',
#  'TEETH, DISCOLORED',
#  'DEHYDRATED',
#  'GUMS',
#  'SCLERA RED',
#  'GENERAL OBSERVATIONS:NORMAL BEHAVIOR',
#  'CRUST PRESENT, FORELIMB, LEFT, SLIGHT',
#  'PUPILLARY REFLEX:NORMAL',
#  'FOOT GRIP REFLEX:NORMAL',
#  'ORBICULARIS-OCULI-REFLEX:NORMAL',
#  'ANAL REFLEX:NORMAL',
#  'ATAXIC',
#  'EYE PROTRUDING',
#  'RECOMMENDED AS REJECTED ANIMAL',
#  'DECREASED BISCUIT INTAKE BUT STILL EATS ENRICHMENT X 24 HOURS',
#  'VOMITUS, FOAMY, WHITE',
#  'SKIN AND FUR:SHEDDING/PEELING SKIN',
#  'TRUNK:DISCOLORED SKIN',
#  '50 CO',
#  'MATERIAL, LIQUID, CLEAR',
#  'CORNEA, OPACITY, MULTIFOCAL',
#  'TEETH:BROKEN',
#  'RESPIRATION:LABORED',
#  'LAME',
#  'TEETH, MISSING',
#  'REDUCED WATER INTAKE',
#  'FLACCIDITY',
#  'OPTIC DISC, PALLOR, FOCAL',
#  'RIGHT EYE:AQUEOUS CELL',
#  'BLANCHING',
#  'FEEDING BEHAVIOR, DECREASED-CAGE-UNIT',
#  'ABDOMINAL RESPIRATION',
#  'PATELLAR REFLEX:NORMAL',
#  'TREMBLING',
#  'EXCRETION:FECES, NONE',
#  'SURFACE RIGHTING REFLEX',
#  'MATERIAL VOMITUS BEIGE',
#  'ANIMAL IN HEAT',
#  'MATERIAL, FOAMY, YELLOW',
#  'SKIN:BRUISE',
#  'SKIN, SCAB FORMATION',
#  'BREATHING, SHALLOW',
#  'FUR - DULL',
#  'BEHAVIOR:PADDLING',
#  'WET MUZZLE',
#  'MATERIAL LIQUID WHITE',
#  'RECUMBENT',
#  'HEADTILT',
#  'APPROVED MORIBUND',
#  'IRIS, PERSISTENT PUPILLARY MEMBRANE, REMNANT',
#  'WATERY FECES',
#  'RATION NOT TOTALLY EATEN (GRP)',
#  'BEHAVIOR:RECUMBENT',
#  'SWELLING AT TREATMENT SITE',
#  'EXCRETA, UNFORMED STOOL',
#  'BULGE',
#  'SWELLING OF VULVA',
#  'ROUGH HAIRCOAT',
#  '75',
#  'TAIL, BENT (PT)',
#  'LETHARGIC',
#  'SKIN AND HAIRCOAT:HAIR LOSS',
#  'INJECTION SITE:ABNORMAL COLOR',
#  'TAPETUM, GRANULAR, APPEARANCE',
#  'HAIRCOAT, ROUGH',
#  'LABORED BREATHING',
#  'DIALATED',
#  'ANIMAL IN ESTRUS (SWELLING + MAT. LIQ. RED VULVA)',
#  'HYPEREXCITABLE',
#  'SLIGHT HAIRLOSS',
#  'ABSENT (NORMAL)',
#  'APPEARANCE:CLONIC CONVULSIONS',
#  'FRACTURE',
#  'FOOD SEMI-QUANTITATIVE 75%',
#  'ANIMAL HEALTH:PROPHYLAXIS',
#  'APPEARANCE ABNORMALITY/THIN',
#  'MATERIAL DRY RED',
#  'TAIL-RINGED',
#  'LEAN',
#  'FECES, W/ PARTICLES',
#  'BEHAVIOR:VOCALIZATION DURING DOSING',
#  'APPEARANCE:TREMORS',
#  'GENERAL, RED STAINING ON CAGE PAPER',
#  'OPACITIES',
#  'MATERIAL MUCOID BROWN',
#  'URINARY COLOUR',
#  'BROKEN TOE NAIL',
#  'MATERIAL LIQUID',
#  'EYEBALL, DARK',
#  'FECES CONTAINING SUSPECT DOSE',
#  'DISCOLORED SKIN',
#  'HAIR ABSENT',
#  'SKIN AND FUR SIGNS:SKIN DISCOLORATION',
#  'ABNORMAL - DESCRIBE IN COMMENT',
#  'MOTOR ACTIVITY DECREASED',
#  'VERY SLIGHT (BARELY PERCEPTIBLE) - 1',
#  'LENS OPACITY, CORTEX, ANTERIOR',
#  'DOSE SITE:ERYTHEMA (0-4)',
#  'EYE PARTLY CLOSED',
#  'RED DISCOLOURED SKIN - DIFFUSE',
#  'LENS OPACITY, CAPSULE, POSTERIOR, MULTIFOCAL',
#  'APPEARANCE ABNORMALITY/ROUGH COAT',
#  'VITREOUS OPACITY, FOCAL, PIGMENTED',
#  'SEBORRHEA',
#  'ESCHAR EXFOLIATION',
#  'GI,   FECES MUCOID',
#  'RESPIRATION:AUDIBLE',
#  'FECES NORMAL',
#  'SKIN, LACERATION',
#  'BEHAVIOUR - SUBDUED',
#  'NO STOOL',
#  'DOSE SITE:EDEMA (0-4)',
#  'EYE FUNDUS:DRUSEN',
#  'FECES-SOFT',
#  '50%',
#  'BREATHING DIFFICULT',
#  'SKIN TOUCH HARD',
#  'OSTIA IS FREE OF DISCHARGE',
#  'RESPIRATION, NOISY',
#  'REDUCED GROOMING',
#  'MATERIAL DRY',
#  'FOOD SEMI-QUANTITATIVE',
#  ...]

# %%
training.shape
# Out:
# (17285, 641)

# %%
training.IS_CONTROL.sum()
# Out:
# 4481

# %%
ts_training = ts[ts.STUDYID.isin(training.STUDYID)]

# %%
17285-4481
# Out:
# 12804

# %%
vals = ts_training[ts_training.TSPARMCD == 'ROUTE'][['STUDYID', 'TSVAL']].drop_duplicates()

# %%
ts_training.STUDYID.unique().shape
# Out:
# (138,)

# %%
vals.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-180-d8d72ada9794> in <module>
# ----> 1 vals.value_counts()
#
# /hive/Anaconda3-2020.02/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
vals.TSVAL.value_counts()
# Out:
# ORAL GAVAGE                 93
# INTRAVENOUS                 19
# INTRAVENOUS BOLUS           12
# SUBCUTANEOUS                 8
# RESPIRATORY (INHALATION)     5
# ORAL                         3
# INTRAVENOUS DRIP             2
# INTRAMUSCULAR                1
# INTRAVITREAL                 1
# INTRATHECAL                  1
# Name: TSVAL, dtype: int64

# %%
96 / 138
# Out:
# 0.6956521739130435
