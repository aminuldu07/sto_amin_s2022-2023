# %%
import pandas as pd

# %%
# Read the CSV file
path = 'C:/Users/mdaminulisla.prodhan/All_My_Miscellenous/Mode_building_bypython/mordred_descriptors_fromSMILES1_with_descriptors_name.csv'
df = pd.read_csv(path)
#df
# Out:
# C:\Users\mdaminulisla.prodhan\AppData\Local\Temp\1\ipykernel_16932\1213946566.py:3: DtypeWarning: Columns (54,55,56,57,58,59,60,61,62,90,91,92,93,94,95,96,97,98,136,137,138,139,140,145,146,147,148,149,153,154,155,156,157,158,163,164,165,166,167,172,173,174,175,176,181,182,183,184,185,189,190,191,192,193,194,199,200,201,202,203,208,209,210,211,212,217,218,219,220,221,226,227,228,229,230,261,262,263,264,265,266,267,268,269,297,298,299,300,301,302,303,304,305,352,353,354,355,356,361,362,363,364,365,369,370,371,372,373,374,379,380,381,382,383,388,389,390,391,392,397,398,399,400,401,405,406,407,408,409,410,415,416,417,418,419,424,425,426,427,428,433,434,435,436,437,442,443,444,445,446,458,459,460,461,462,466,467,468,469,470,474,475,476,477,478,482,483,484,485,486,490,491,492,493,494,498,499,500,501,502,506,507,508,509,510,514,515,516,517,518,522,523,524,525,526,530,531,532,533,534,538,539,540,541,542,554,555,556,557,558,562,563,564,565,566,570,571,572,573,574,578,579,580,581,582,586,587,5
# ...

# %%
#get the index of a DataFrame df
print(df.index)
# Out:
# RangeIndex(start=0, stop=574, step=1)

# %%
# get the name of the first column of the DataFrame df
first_column_name = df.columns[0]
first_column_name
# Out:
# 'Unnamed: 0'

# %%
# get the first column of the DataFrame df
first_column = df.iloc[:, 0]
first_column
# Out:
# 0      [2H][C@@](C)(NC(=O)COC(F)F)c1cc(F)cc(Cl)c1COc2...
# 1                                 [2H][C@@](N)(CO)C(O)=O
# 2      [2H]C([2H])([2H])N(C([2H])([2H])[2H])C([2H])([...
# 3      [2H]C1([2H])[C@H]2C[C@@H](Oc3ccc(cn3)C(F)(F)F)...
# 4      [2H]C1([2H])C([C@@H](CC#N)n2cc(cn2)-c3ncnc4[nH...
#                              ...
# 569    OS(O)(=O)=O.C[C@H](N)Cc1ccccc1.C[C@H](N)Cc2ccccc2
# 570    OS(O)(=O)=O.COc1ccc(cc1)S(=O)(=O)NCc2cc(CN3CCC...
# 571    OS(O)(=O)=O.N[C@H]1C[C@@H]1c2ccccc2.N[C@H]3C[C...
# 572    OS(O)(=O)=O.O[C@H]1CCN(C1)C(=O)Nc2cnn3ccc(nc23...
# 573                         SCCNC(=O)c1cccc(c1)C(=O)NCCS
# Name: Unnamed: 0, Length: 574, dtype: object

# %%
#df

# %%
# rename the first column of your DataFrame df to "SMILES"
df.rename(columns={df.columns[0]: 'SMILES'}, inplace=True)
#df

# %%
# get the name of the first column of the DataFrame df
first_column_name = df.columns[0]
first_column_name
# Out:
# 'SMILES'

# %%
# Write the DataFrame to a CSV file
#df.to_csv("df_SMILES.csv", index=False)

# %%
# Read the CSV file
path = 'C:/Users/mdaminulisla.prodhan/All_My_Miscellenous/Mode_building_bypython/df_SMILES.csv'
df_smiles = pd.read_csv(path)
df
# Out:
# C:\Users\mdaminulisla.prodhan\AppData\Local\Temp\1\ipykernel_16932\2327069247.py:3: DtypeWarning: Columns (54,55,56,57,58,59,60,61,62,90,91,92,93,94,95,96,97,98,136,137,138,139,140,145,146,147,148,149,153,154,155,156,157,158,163,164,165,166,167,172,173,174,175,176,181,182,183,184,185,189,190,191,192,193,194,199,200,201,202,203,208,209,210,211,212,217,218,219,220,221,226,227,228,229,230,261,262,263,264,265,266,267,268,269,297,298,299,300,301,302,303,304,305,352,353,354,355,356,361,362,363,364,365,369,370,371,372,373,374,379,380,381,382,383,388,389,390,391,392,397,398,399,400,401,405,406,407,408,409,410,415,416,417,418,419,424,425,426,427,428,433,434,435,436,437,442,443,444,445,446,458,459,460,461,462,466,467,468,469,470,474,475,476,477,478,482,483,484,485,486,490,491,492,493,494,498,499,500,501,502,506,507,508,509,510,514,515,516,517,518,522,523,524,525,526,530,531,532,533,534,538,539,540,541,542,554,555,556,557,558,562,563,564,565,566,570,571,572,573,574,578,579,580,581,582,586,587,5
# ...

# %%
# get the first column of the DataFrame df
first_column = df_smiles.iloc[:, 0]
first_column
# Out:
# 0      [2H][C@@](C)(NC(=O)COC(F)F)c1cc(F)cc(Cl)c1COc2...
# 1                                 [2H][C@@](N)(CO)C(O)=O
# 2      [2H]C([2H])([2H])N(C([2H])([2H])[2H])C([2H])([...
# 3      [2H]C1([2H])[C@H]2C[C@@H](Oc3ccc(cn3)C(F)(F)F)...
# 4      [2H]C1([2H])C([C@@H](CC#N)n2cc(cn2)-c3ncnc4[nH...
#                              ...
# 569    OS(O)(=O)=O.C[C@H](N)Cc1ccccc1.C[C@H](N)Cc2ccccc2
# 570    OS(O)(=O)=O.COc1ccc(cc1)S(=O)(=O)NCc2cc(CN3CCC...
# 571    OS(O)(=O)=O.N[C@H]1C[C@@H]1c2ccccc2.N[C@H]3C[C...
# 572    OS(O)(=O)=O.O[C@H]1CCN(C1)C(=O)Nc2cnn3ccc(nc23...
# 573                         SCCNC(=O)c1cccc(c1)C(=O)NCCS
# Name: SMILES, Length: 574, dtype: object

# %%
# Setting the "SMILES" column as index 
df_smiles.set_index('SMILES', inplace=True)
df_smiles
# Out:
#                                                           ABC      ABCGG  \
# SMILES
# [2H][C@@](C)(NC(=O)COC(F)F)c1cc(F)cc(Cl)c1COc2c...  29.730254  23.609807
# [2H][C@@](N)(CO)C(O)=O                               5.424755   5.968663
# [2H]C([2H])([2H])N(C([2H])([2H])[2H])C([2H])([2...  19.620859  18.638910
# [2H]C1([2H])[C@H]2C[C@@H](Oc3ccc(cn3)C(F)(F)F)[...  28.122628  21.855309
# [2H]C1([2H])C([C@@H](CC#N)n2cc(cn2)-c3ncnc4[nH]...  24.703357  21.962502
# ...                                                       ...        ...
# OS(O)(=O)=O.C[C@H](N)Cc1ccccc1.C[C@H](N)Cc2ccccc2   18.043796  17.031026
# OS(O)(=O)=O.COc1ccc(cc1)S(=O)(=O)NCc2cc(CN3CCCC...  28.497576  23.444997
# OS(O)(=O)=O.N[C@H]1C[C@@H]1c2ccccc2.N[C@H]3C[C@...  19.077470  18.591048
# OS(O)(=O)=O.O[C@H]1CCN(C1)C(=O)Nc2cnn3ccc(nc23)...  28.367317  23.607064
# SCCNC(=O)c1cccc(c1)C(=O)NCCS                        12.865821  11.469555
#
#                                                     nAcid  nBase  \
# SMILES
# ...

# %%
# data pre-processing
# df_smiles's different column has different data type

# %%
# data type checking 

data_type_df_columns = print(df_smiles.dtypes)
dat_type_df
# Out:
# ABC         float64
# ABCGG       float64
# nAcid         int64
# nBase         int64
# SpAbs_A      object
#              ...
# WPol          int64
# Zagreb1     float64
# Zagreb2     float64
# mZagreb1     object
# mZagreb2    float64
# Length: 1613, dtype: object

# %%
#  Convert all columns to numeric
df_numeric = df_smiles.apply(pd.to_numeric, errors='coerce')
# Save the DataFrame to a CSV file

# %%
# # Apply to_numeric to all columns except the first one
# df.iloc[:, 1:] = df.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')

# # Rename the first column as 'SMILES'
# df.rename(columns={df.columns[0]: 'SMILES'}, inplace=True)

# # Write the DataFrame to a CSV file
# df.to_csv("df_numeric.csv", index=False)

# %%
df_numeric
#df_numeric.to_csv('C:/Users/mdaminulisla.prodhan/All_My_Miscellenous/Mode_building_bypython/df_numeric.csv')
# Out:
#                                                           ABC      ABCGG  \
# SMILES
# [2H][C@@](C)(NC(=O)COC(F)F)c1cc(F)cc(Cl)c1COc2c...  29.730254  23.609807
# [2H][C@@](N)(CO)C(O)=O                               5.424755   5.968663
# [2H]C([2H])([2H])N(C([2H])([2H])[2H])C([2H])([2...  19.620859  18.638910
# [2H]C1([2H])[C@H]2C[C@@H](Oc3ccc(cn3)C(F)(F)F)[...  28.122628  21.855309
# [2H]C1([2H])C([C@@H](CC#N)n2cc(cn2)-c3ncnc4[nH]...  24.703357  21.962502
# ...                                                       ...        ...
# OS(O)(=O)=O.C[C@H](N)Cc1ccccc1.C[C@H](N)Cc2ccccc2   18.043796  17.031026
# OS(O)(=O)=O.COc1ccc(cc1)S(=O)(=O)NCc2cc(CN3CCCC...  28.497576  23.444997
# OS(O)(=O)=O.N[C@H]1C[C@@H]1c2ccccc2.N[C@H]3C[C@...  19.077470  18.591048
# OS(O)(=O)=O.O[C@H]1CCN(C1)C(=O)Nc2cnn3ccc(nc23)...  28.367317  23.607064
# SCCNC(=O)c1cccc(c1)C(=O)NCCS                        12.865821  11.469555
#
#                                                     nAcid  nBase    SpAbs_A  \
# ...

# %%
new_df = df_numeric
new_df
# Out:
#                                                           ABC      ABCGG  \
# SMILES
# [2H][C@@](C)(NC(=O)COC(F)F)c1cc(F)cc(Cl)c1COc2c...  29.730254  23.609807
# [2H][C@@](N)(CO)C(O)=O                               5.424755   5.968663
# [2H]C([2H])([2H])N(C([2H])([2H])[2H])C([2H])([2...  19.620859  18.638910
# [2H]C1([2H])[C@H]2C[C@@H](Oc3ccc(cn3)C(F)(F)F)[...  28.122628  21.855309
# [2H]C1([2H])C([C@@H](CC#N)n2cc(cn2)-c3ncnc4[nH]...  24.703357  21.962502
# ...                                                       ...        ...
# OS(O)(=O)=O.C[C@H](N)Cc1ccccc1.C[C@H](N)Cc2ccccc2   18.043796  17.031026
# OS(O)(=O)=O.COc1ccc(cc1)S(=O)(=O)NCc2cc(CN3CCCC...  28.497576  23.444997
# OS(O)(=O)=O.N[C@H]1C[C@@H]1c2ccccc2.N[C@H]3C[C@...  19.077470  18.591048
# OS(O)(=O)=O.O[C@H]1CCN(C1)C(=O)Nc2cnn3ccc(nc23)...  28.367317  23.607064
# SCCNC(=O)c1cccc(c1)C(=O)NCCS                        12.865821  11.469555
#
#                                                     nAcid  nBase    SpAbs_A  \
# ...

# %%
#get the index of a DataFrame 
print(new_df.index)
# Out:
# Index(['[2H][C@@](C)(NC(=O)COC(F)F)c1cc(F)cc(Cl)c1COc2cccc3c(cc(C)nc23)-c4ncnn4C',
#        '[2H][C@@](N)(CO)C(O)=O',
#        '[2H]C([2H])([2H])N(C([2H])([2H])[2H])C([2H])([2H])C([2H])([2H])c1c[nH]c2cccc(O)c12',
#        '[2H]C1([2H])[C@H]2C[C@@H](Oc3ccc(cn3)C(F)(F)F)[C@H](C2)N1C(=O)c4cccc(F)c4-c5ncccn5',
#        '[2H]C1([2H])C([C@@H](CC#N)n2cc(cn2)-c3ncnc4[nH]ccc34)C([2H])([2H])C([2H])([2H])C1([2H])[2H]',
#        '[68Ga+3].[H][C@]1(CC(F)(F)CN1C(=O)CNC(=O)c2ccnc3ccc(cc23)N(C)CCCN4CCN(CC4)C(=O)CN5CCN(CC([O-])=O)CCN(CC([O-])=O)CCN(CC([O-])=O)CC5)C#N',
#        '[68Ga+3].[H][C@]2(Cc1ccc(NC(N)=O)cc1)NC(=O)[C@H](Cc3ccc(NC(=O)[C@@H]4CC(=O)NC(=O)N4)cc3)NC(=O)[C@@H](CSSC[C@H](NC(=O)[C@@]([H])(NC(=O)[C@H](CCCCN)NC2=O)[C@@H](C)O)C(=O)N[C@H](Cc5ccc(O)cc5)C(N)=O)NC(=O)[C@H](Cc6ccc(Cl)cc6)NC(=O)CCC(N7CCN(CC([O-])=O)CCN(CC([O-])=O)CC7)C([O-])=O',
#        '[Br-].CCOC(=O)C[N+]1(C)CC[C@H](C1)OC(=O)[C@@](O)(C2CCCC2)c3ccccc3',
#        '[C-]#[O+]',
# ...

# %%
############## Handling NaN valus in df ###############################

# Count the number of NaN values in each column
nan_counts = df_numeric.isna().sum()

# Convert the Series to a DataFrame
nan_counts_df = pd.DataFrame(nan_counts, columns=["NaN count"])

# Write the DataFrame to a CSV file
nan_counts_df.to_csv("nan_counts.csv")

# %%
# Compute the number of NaN in each column
nan_counts = new_df.iloc[:, 1:].isna().sum()

# Define the columns where the NaN count is less than or equal to 1
columns_leq1 = nan_counts[nan_counts <= 1].index

# Define the columns where the NaN count is more than 1
columns_gt1 = nan_counts[nan_counts > 1].index

# Create the first dataframe
df1 = new_df.loc[:, [new_df.columns[0]] + list(columns_leq1)].copy()

# Create the second dataframe
df2 = new_df.loc[:, [new_df.columns[0]] + list(columns_gt1)].copy()

# %%
#df1
# Out:
#                                                           ABC      ABCGG  \
# SMILES
# [2H][C@@](C)(NC(=O)COC(F)F)c1cc(F)cc(Cl)c1COc2c...  29.730254  23.609807
# [2H][C@@](N)(CO)C(O)=O                               5.424755   5.968663
# [2H]C([2H])([2H])N(C([2H])([2H])[2H])C([2H])([2...  19.620859  18.638910
# [2H]C1([2H])[C@H]2C[C@@H](Oc3ccc(cn3)C(F)(F)F)[...  28.122628  21.855309
# [2H]C1([2H])C([C@@H](CC#N)n2cc(cn2)-c3ncnc4[nH]...  24.703357  21.962502
# ...                                                       ...        ...
# OS(O)(=O)=O.C[C@H](N)Cc1ccccc1.C[C@H](N)Cc2ccccc2   18.043796  17.031026
# OS(O)(=O)=O.COc1ccc(cc1)S(=O)(=O)NCc2cc(CN3CCCC...  28.497576  23.444997
# OS(O)(=O)=O.N[C@H]1C[C@@H]1c2ccccc2.N[C@H]3C[C@...  19.077470  18.591048
# OS(O)(=O)=O.O[C@H]1CCN(C1)C(=O)Nc2cnn3ccc(nc23)...  28.367317  23.607064
# SCCNC(=O)c1cccc(c1)C(=O)NCCS                        12.865821  11.469555
#
#                                                     nAcid  nBase  nAromAtom  \
# ...

# %%
# # Write the DataFrame to a CSV file
# df1.to_csv("df1_nan_counts_columns_leq1.csv")
# # Write the DataFrame to a CSV file
# df2.to_csv("df2_nan_counts_columns_gt1.csv")

# %%
#df1

# %%
############## Handling "0" valus in df ###############################

# %%
##### wwork on "df1 = where the NaN count is more than 1"

# %%
# Count the number of '0' values in each column
zero_counts = (df_numeric == 0).sum()

# Convert the Series to a DataFrame
zero_counts_df = pd.DataFrame(zero_counts, columns=["Zero count"])

# Write the DataFrame to a CSV file
#zero_counts_df.to_csv("zero_counts.csv")

zero_counts_df
# Out:
#           Zero count
# ABC                3
# ABCGG              3
# nAcid            424
# nBase            321
# SpAbs_A            0
# ...              ...
# WPol               5
# Zagreb1            2
# Zagreb2            2
# mZagreb1           0
# mZagreb2           2
#
# [1613 rows x 1 columns]

# %%
zero_counts_df  .to_csv("zero_counts_df  .csv")

# %%
# #the first column is included in both df1_filtered and df2 data frames

# # Compute the number of "0" values in each column
# zero_counts = df1.iloc[:, 1:].eq(0).sum()

# # Define the columns where the count of "0" values is less than or equal to 1
# columns_leq1 = zero_counts[zero_counts <= 1].index

# # Define the columns where the count of "0" values is more than 1
# columns_gt1 = zero_counts[zero_counts > 1].index

# # Create the first data frame
# df1_filtered = df1.loc[:, [df1.columns[0]] + list(columns_leq1)].copy()

# # Create the second data frame
# df2 = df1.loc[:, [df1.columns[0]] + list(columns_gt1)].copy()

# %%
#df1_filtered 
#df1_filtered .to_csv("df1_filtered .csv")

# %%
# # Compute the count of zeros in the "ABC" column
# zero_count_ABC = (df1["ABC"] == 0).sum()

# print("Zero count in the 'ABC' column:", zero_count_ABC)

# %%
# rows_with_zero = df1_filtered[df1_filtered['ABC'] == 0]
# data_types = rows_with_zero.dtypes

# %%
# Compute the number of "0" values in each column
zero_counts = df1.iloc[:, 0:].eq(0).sum()

# Define the columns where the count of "0" values is less than or equal to 1
columns_leq1 = zero_counts[zero_counts <= 1].index

# Define the columns where the count of "0" values is more than 1
columns_gt1 = zero_counts[zero_counts > 1].index

# Create the first data frame
df1_filtered = df1.loc[:, columns_leq1].copy()

# Create the second data frame
df2_filtered = df1.loc[:, columns_gt1].copy()

# %%
zero_counts
zero_counts.to_csv("zero_count_in_df1.csv")

# %%
df2_filtered
# Out:
#                                                           ABC      ABCGG  \
# SMILES
# [2H][C@@](C)(NC(=O)COC(F)F)c1cc(F)cc(Cl)c1COc2c...  29.730254  23.609807
# [2H][C@@](N)(CO)C(O)=O                               5.424755   5.968663
# [2H]C([2H])([2H])N(C([2H])([2H])[2H])C([2H])([2...  19.620859  18.638910
# [2H]C1([2H])[C@H]2C[C@@H](Oc3ccc(cn3)C(F)(F)F)[...  28.122628  21.855309
# [2H]C1([2H])C([C@@H](CC#N)n2cc(cn2)-c3ncnc4[nH]...  24.703357  21.962502
# ...                                                       ...        ...
# OS(O)(=O)=O.C[C@H](N)Cc1ccccc1.C[C@H](N)Cc2ccccc2   18.043796  17.031026
# OS(O)(=O)=O.COc1ccc(cc1)S(=O)(=O)NCc2cc(CN3CCCC...  28.497576  23.444997
# OS(O)(=O)=O.N[C@H]1C[C@@H]1c2ccccc2.N[C@H]3C[C@...  19.077470  18.591048
# OS(O)(=O)=O.O[C@H]1CCN(C1)C(=O)Nc2cnn3ccc(nc23)...  28.367317  23.607064
# SCCNC(=O)c1cccc(c1)C(=O)NCCS                        12.865821  11.469555
#
#                                                     nAcid  nBase  nAromAtom  \
# ...

# %%
df1_filtered
# Out:
#                                                     nAtom  nHeavyAtom  \
# SMILES
# [2H][C@@](C)(NC(=O)COC(F)F)c1cc(F)cc(Cl)c1COc2c...     60          38
# [2H][C@@](N)(CO)C(O)=O                                 14           8
# [2H]C([2H])([2H])N(C([2H])([2H])[2H])C([2H])([2...     31          25
# [2H]C1([2H])[C@H]2C[C@@H](Oc3ccc(cn3)C(F)(F)F)[...     51          35
# [2H]C1([2H])C([C@@H](CC#N)n2cc(cn2)-c3ncnc4[nH]...     41          31
# ...                                                   ...         ...
# OS(O)(=O)=O.C[C@H](N)Cc1ccccc1.C[C@H](N)Cc2ccccc2      53          25
# OS(O)(=O)=O.COc1ccc(cc1)S(=O)(=O)NCc2cc(CN3CCCC...     72          37
# OS(O)(=O)=O.N[C@H]1C[C@@H]1c2ccccc2.N[C@H]3C[C@...     49          25
# OS(O)(=O)=O.O[C@H]1CCN(C1)C(=O)Nc2cnn3ccc(nc23)...     60          36
# SCCNC(=O)c1cccc(c1)C(=O)NCCS                           34          18
#
#                                                     nHetero      ATS0dv  \
# SMILES
# ...

# %%
# # # # Write the DataFrame to a CSV file
df1_filtered.to_csv("df1_filtered .csv")
    
# # Write the DataFrame to a CSV file
df2_filtered.to_csv("df2_filtered .csv")

# %%
df2[ABCGG]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\1\ipykernel_16932\3198738073.py in <module>
# ----> 1 df2[ABCGG]
#
# NameError: name 'ABCGG' is not defined

# %%
import pubchempy as pcp
